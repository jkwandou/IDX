# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import csv

# %%
sold1 = pd.read_csv('raw/CRMLSSold202401_filled.csv')
sold2 = pd.read_csv('raw/CRMLSSold202402_filled.csv')
sold3 = pd.read_csv('raw/CRMLSSold202403_filled.csv')
sold4 = pd.read_csv('raw/CRMLSSold202404_filled.csv')
sold5 = pd.read_csv('raw/CRMLSSold202405_filled.csv')
sold6 = pd.read_csv('raw/CRMLSSold202406_filled.csv')
sold7 = pd.read_csv('raw/CRMLSSold202407_filled.csv')
sold8 = pd.read_csv('raw/CRMLSSold202408.csv')
sold9 = pd.read_csv('raw/CRMLSSold202409.csv')
sold10 = pd.read_csv('raw/CRMLSSold202410.csv')
sold11 = pd.read_csv('raw/CRMLSSold202411.csv')
sold12 = pd.read_csv('raw/CRMLSSold202412.csv')
sold13 = pd.read_csv('raw/CRMLSSold202501_filled.csv')
sold14 = pd.read_csv('raw/CRMLSSold202502.csv')
sold15 = pd.read_csv('raw/CRMLSSold202503.csv')
sold16 = pd.read_csv('raw/CRMLSSold202504.csv')
sold17 = pd.read_csv('raw/CRMLSSold202505.csv')
sold18 = pd.read_csv('raw/CRMLSSold202506.csv')
sold19 = pd.read_csv('raw/CRMLSSold202507.csv')
sold20 = pd.read_csv('raw/CRMLSSold202508.csv')
sold21 = pd.read_csv('raw/CRMLSSold202509.csv')
sold22 = pd.read_csv('raw/CRMLSSold202510.csv')
sold23 = pd.read_csv('raw/CRMLSSold202511.csv')
sold24 = pd.read_csv('raw/CRMLSSold202512.csv')
sold25 = pd.read_csv('raw/CRMLSSold202601.csv')
sold26 = pd.read_csv('raw/CRMLSSold202602.csv')
sold27 = pd.read_csv('raw/CRMLSSold202603.csv')
# Out:
# /var/folders/13/041lbv8n5d1clk4p9mt3qr540000gp/T/ipykernel_11086/3805943219.py:4: DtypeWarning: Columns (2,36,39,56,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   sold4 = pd.read_csv('raw/CRMLSSold202404_filled.csv')
# /var/folders/13/041lbv8n5d1clk4p9mt3qr540000gp/T/ipykernel_11086/3805943219.py:18: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   sold18 = pd.read_csv('raw/CRMLSSold202506.csv')
# /var/folders/13/041lbv8n5d1clk4p9mt3qr540000gp/T/ipykernel_11086/3805943219.py:25: DtypeWarning: Columns (4,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   sold25 = pd.read_csv('raw/CRMLSSold202601.csv')

# %%
sold = pd.concat([sold1, sold2, sold3, sold4, sold5, sold6, sold7, sold8, sold9, sold10, sold11, sold12, sold13, sold14, sold15, sold16, sold17, sold18, sold19, sold20, sold21, sold22, sold23, sold24, sold25, sold26, sold27], ignore_index=True)
len(sold)
# Out:
# 591715

# %%
sold_filtered = sold[sold.PropertyType == 'Residential']
len(sold_filtered)
# Out:
# 397594

# %%
sold_filtered.to_csv('/Users/jessicakwandou/Documents/IDX Exchange/sold.csv', index=False)
